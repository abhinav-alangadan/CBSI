# %%
# !pip install cbsi
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import cbsi

# %%
import matplotlib.pyplot as plt
import numpy as np
import gdal

# %%
data = gdal.Open('/content/drive/MyDrive/NDVI_Kerala/clip.tif').ReadAsArray()

# %%
data = data/(data.max()/255.0)

# %%
img=np.dstack((data[3],data[2],data[1]))

# %%
plt.imshow(img.astype(np.uint8))

# %%
cbsi_ndvi = cbsi.ndvi(data)

# %%
plt.imshow(cbsi_ndvi, cmap='gray')
